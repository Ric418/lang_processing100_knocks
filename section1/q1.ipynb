# %% [markdown]
# # 01.「パタトクカシーー」
# 「パタトクカシーー」という文字列の1,3,5,7文字目を取り出して連結した文字列を得よ．

# %%
text="パタトクカシーー"

# %% [markdown]
# ## スライスとステップを用いる
# 今回は最初(0)から最後までを2ステップで表示している

# %%
text[0::2]
# Out:
# 'パトカー'

# %% [markdown]
# ## ちなみにタクシーの場合は
# 2文字目から

# %%
text[1::2]
# Out:
# 'タクシー'

# %% [markdown]
# ## for文だと

# %%
for num in range(0,len(text),2):
    print(text[num],text[num+1])
# Out:
# パ タ
# ト ク
# カ シ
# ー ー
